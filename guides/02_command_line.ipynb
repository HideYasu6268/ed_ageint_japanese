# %% [markdown]
# # コマンドライン

# %% [markdown]
# コマンドラインでの操作に自信を持てるようになるためのガイドへようこそ。
#
# このガイドを終える頃には、ディレクトリの作成やファイルの移動など、コマンドラインでの操作を自信を持って行えるようになっているはずです!

# %% [markdown]
# ## Windows PCをお使いの方へ
#
# こちらの説明資料をご覧ください。
#
# https://chatgpt.com/share/68064acf-4d3c-8012-86a1-fb09a7c6f923

# %% [markdown]
# ## Macをお使いの方へ
#
# こちらの説明資料をご覧ください。
#
# https://chatgpt.com/share/68064bfe-662c-8012-8073-479c32595459

# %% [markdown]
# 自信をつけるために、ぜひいろいろ試してみてください。
#
# ChatGPT、Claude、Gemini、DeepSeekなどはあなたの強い味方です!これらはコマンドラインのコマンドを詳しく説明するのが得意です。すぐに自然と身についていくでしょう。
